# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
## Checking the GPU configuration
# !nvidia-smi
# Out:
# Sun Aug  6 15:38:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import os
import datetime
import imageio
from skimage.transform import resize
#from scipy.misc import imread, imresize
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
#tf.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('/kaggle/input/gesture-recognition/train.csv').readlines())
val_doc = np.random.permutation(open('/kaggle/input/gesture-recognition/val.csv').readlines())
batch_size = 64

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
#visualizing a sample random image
sample_image = imageio.imread('/kaggle/input/gesture-recognition/train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00054.png')
plt.imshow(sample_image)

# %%
#checking the shape of random image
sample_image.shape
# Out:
# (360, 360, 3)

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = range(0,30,2) #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,len(img_idx),60,60,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    image = resize(image,(60,60))
                    image = image - np.percentile(image,5)/ np.percentile(image,95) - np.percentile(image,5)
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = image[:,:,0]
                    batch_data[folder,idx,:,:,1] = image[:,:,1]
                    batch_data[folder,idx,:,:,2] = image[:,:,2]
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,len(img_idx),60,60,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    image = resize(image,(60,60))
                    image = image - np.percentile(image,5)/ np.percentile(image,95) - np.percentile(image,5)
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = image[:,:,0]
                    batch_data[folder,idx,:,:,1] = image[:,:,1]
                    batch_data[folder,idx,:,:,2] = image[:,:,2]
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/kaggle/input/gesture-recognition/train'
val_path = '/kaggle/input/gesture-recognition/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 50
# choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.regularizers import l2
from keras.layers import LSTM, GRU, Bidirectional, SimpleRNN, RNN

model = Sequential()

model.add(TimeDistributed(Conv2D(16, (2, 2), padding='same'),
                 input_shape=(15,60,60,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(Conv2D(16, (2, 2))))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(Dropout(0.2))

model.add(TimeDistributed(Conv2D(32, (2, 2), padding='same')))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(Conv2D(32, (2, 2), padding='same')))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(Dropout(0.2))

model.add(TimeDistributed(Flatten()))
model.add(LSTM(256, return_sequences=False, dropout=0.5))
model.add(Dense(64,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(5))
model.add(Activation('softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
model.compile(loss='categorical_crossentropy', optimizer = 'sgd', metrics=['categorical_accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 15, 60, 60, 16)   208
#  ibuted)
#
#  activation (Activation)     (None, 15, 60, 60, 16)    0
#
#  batch_normalization (BatchN  (None, 15, 60, 60, 16)   64
#  ormalization)
#
#  time_distributed_1 (TimeDis  (None, 15, 59, 59, 16)   1040
#  tributed)
#
#  activation_1 (Activation)   (None, 15, 59, 59, 16)    0
#
#  batch_normalization_1 (Batc  (None, 15, 59, 59, 16)   64
#  hNormalization)
#
#  time_distributed_2 (TimeDis  (None, 15, 29, 29, 16)   0
#  tributed)
#
#  dropout (Dropout)           (None, 15, 29, 29, 16)    0
#
#  time_distributed_3 (TimeDis  (None, 15, 29, 29, 32)   2080
#  tributed)
#
#  activation_2 (Activation)   (None, 15, 29, 29, 32)    0
#
#  batch_normalization_2 (Batc  (None, 15, 29, 29, 32)   128
#  hNormalization)
#
#  time_distributed_4 (TimeDis  (None, 15, 29, 29, 32)   4128
#  tributed)
#
#  activation_3 (Activation)   (None, 15, 29, 29, 32)    0
#
#  batch_normalization_3 (Batc  (None, 15, 29, 29, 32)   128
#  hNormalization)
#
#  time_distributed_5 (TimeDis  (None, 15, 14, 14, 32)   0
#  tributed)
#
#  dropout_1 (Dropout)         (None, 15, 14, 14, 32)    0
#
#  time_distributed_6 (TimeDis  (None, 15, 6272)         0
#  tributed)
#
#  lstm (LSTM)                 (None, 256)               6685696
#
#  dense (Dense)               (None, 64)                16448
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
#  activation_5 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 6,710,309
# Trainable params: 6,710,117
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor = "val_loss", factor = 0.2, patience = 5, min_lr=0.01)
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /kaggle/input/gesture-recognition/train ; batch size = 64
# Epoch 1/50
#  9/11 [=======================>......] - ETA: 23s - loss: 2.7271 - categorical_accuracy: 0.2170Batch:  11 Index: 64
# 11/11 [==============================] - ETA: 0s - loss: 2.7187 - categorical_accuracy: 0.2157 Source path =  /kaggle/input/gesture-recognition/val ; batch size = 64
# Batch:  2 Index: 64
#
# Epoch 1: saving model to model_init_2023-08-0615_38_25.467864/model-00001-2.71871-0.21569-2.69342-0.16000.h5
# 11/11 [==============================] - 147s 13s/step - loss: 2.7187 - categorical_accuracy: 0.2157 - val_loss: 2.6934 - val_categorical_accuracy: 0.1600 - lr: 0.0100
# Epoch 2/50
# 11/11 [==============================] - ETA: 0s - loss: 2.6568 - categorical_accuracy: 0.2253Batch:  3 Index: 36
#
# Epoch 2: saving model to model_init_2023-08-0615_38_25.467864/model-00002-2.65677-0.22530-2.73968-0.23438.h5
# 11/11 [==============================] - 51s 5s/step - loss: 2.6568 - categorical_accuracy: 0.2253 - val_loss: 2.7397 - val_categorical_accuracy: 0.2344 - lr: 0.0100
# Epoch 3/50
# 11/11 [==============================] - ETA: 0s - loss: 2.5808 - categorical_accuracy: 0.2885Batch:  4 Index: 28
#
# Epoch 3: saving model to model_init_2023-08-0615_38_25.467864/model-00003-2.58078-0.28854-2.76257-0.23214.h5
# 11/11 [==============================] - 42s 4s/step - loss: 2.5808 - categorical_accuracy: 0.2885 - val_loss: 2.7626 - val_categorical_accuracy: 0.2321 - lr: 0.0100
# Epoch 4/50
#  5/11 [============>.................] - ETA: 18s - loss: 2.4893 - categorical_accuracy: 0.4000Batch:  29 Index: 23
# 11/11 [==============================] - ETA: 0s - loss: 2.5169 - categorical_accuracy: 0.3562
# Epoch 4: saving model to model_init_2023-08-0615_38_25.467864/model-00004-2.51686-0.35622-2.73628-0.25000.h5
# 11/11 [==============================] - 35s 3s/step - loss: 2.5169 - categorical_accuracy: 0.3562 - val_loss: 2.7363 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 5/50
# 11/11 [==============================] - ETA: 0s - loss: 2.4570 - categorical_accuracy: 0.3684
# Epoch 5: saving model to model_init_2023-08-0615_38_25.467864/model-00005-2.45695-0.36842-3.19848-0.25000.h5
# 11/11 [==============================] - 33s 3s/step - loss: 2.4570 - categorical_accuracy: 0.3684 - val_loss: 3.1985 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 6/50
# 11/11 [==============================] - ETA: 0s - loss: 2.3685 - categorical_accuracy: 0.4545Batch:  7 Index: 16
#
# Epoch 6: saving model to model_init_2023-08-0615_38_25.467864/model-00006-2.36854-0.45455-2.74169-0.25000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 2.3685 - categorical_accuracy: 0.4545 - val_loss: 2.7417 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 7/50
#  7/11 [==================>...........] - ETA: 9s - loss: 2.3179 - categorical_accuracy: 0.4662 Batch:  35 Index: 19
# 11/11 [==============================] - ETA: 0s - loss: 2.3035 - categorical_accuracy: 0.4729
# Epoch 7: saving model to model_init_2023-08-0615_38_25.467864/model-00007-2.30352-0.47291-3.36577-0.12500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 2.3035 - categorical_accuracy: 0.4729 - val_loss: 3.3658 - val_categorical_accuracy: 0.1250 - lr: 0.0100
# Epoch 8/50
# 11/11 [==============================] - ETA: 0s - loss: 2.3395 - categorical_accuracy: 0.4011
# Epoch 8: saving model to model_init_2023-08-0615_38_25.467864/model-00008-2.33947-0.40107-3.41355-0.12500.h5
# 11/11 [==============================] - 25s 3s/step - loss: 2.3395 - categorical_accuracy: 0.4011 - val_loss: 3.4135 - val_categorical_accuracy: 0.1250 - lr: 0.0100
# Epoch 9/50
# 11/11 [==============================] - ETA: 0s - loss: 2.1907 - categorical_accuracy: 0.5187
# Epoch 9: saving model to model_init_2023-08-0615_38_25.467864/model-00009-2.19073-0.51872-3.50511-0.25000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 2.1907 - categorical_accuracy: 0.5187 - val_loss: 3.5051 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 10/50
# 11/11 [==============================] - ETA: 0s - loss: 2.1633 - categorical_accuracy: 0.5455
# Epoch 10: saving model to model_init_2023-08-0615_38_25.467864/model-00010-2.16329-0.54545-2.59797-0.62500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 2.1633 - categorical_accuracy: 0.5455 - val_loss: 2.5980 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 11/50
# 11/11 [==============================] - ETA: 0s - loss: 2.1169 - categorical_accuracy: 0.5455
# Epoch 11: saving model to model_init_2023-08-0615_38_25.467864/model-00011-2.11692-0.54545-2.98237-0.00000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 2.1169 - categorical_accuracy: 0.5455 - val_loss: 2.9824 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 12/50
# 11/11 [==============================] - ETA: 0s - loss: 2.0723 - categorical_accuracy: 0.5775
# Epoch 12: saving model to model_init_2023-08-0615_38_25.467864/model-00012-2.07233-0.57754-2.29435-0.50000.h5
# 11/11 [==============================] - 23s 2s/step - loss: 2.0723 - categorical_accuracy: 0.5775 - val_loss: 2.2944 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 13/50
# 11/11 [==============================] - ETA: 0s - loss: 2.0177 - categorical_accuracy: 0.5722
# Epoch 13: saving model to model_init_2023-08-0615_38_25.467864/model-00013-2.01772-0.57219-3.40488-0.00000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 2.0177 - categorical_accuracy: 0.5722 - val_loss: 3.4049 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 14/50
# 11/11 [==============================] - ETA: 0s - loss: 2.0927 - categorical_accuracy: 0.5187
# Epoch 14: saving model to model_init_2023-08-0615_38_25.467864/model-00014-2.09275-0.51872-3.12608-0.37500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 2.0927 - categorical_accuracy: 0.5187 - val_loss: 3.1261 - val_categorical_accuracy: 0.3750 - lr: 0.0100
# Epoch 15/50
# 11/11 [==============================] - ETA: 0s - loss: 2.0584 - categorical_accuracy: 0.5508
# Epoch 15: saving model to model_init_2023-08-0615_38_25.467864/model-00015-2.05840-0.55080-2.31815-0.50000.h5
# 11/11 [==============================] - 23s 2s/step - loss: 2.0584 - categorical_accuracy: 0.5508 - val_loss: 2.3181 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 16/50
# 11/11 [==============================] - ETA: 0s - loss: 1.9373 - categorical_accuracy: 0.6257
# Epoch 16: saving model to model_init_2023-08-0615_38_25.467864/model-00016-1.93733-0.62567-2.49216-0.37500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.9373 - categorical_accuracy: 0.6257 - val_loss: 2.4922 - val_categorical_accuracy: 0.3750 - lr: 0.0100
# Epoch 17/50
# 11/11 [==============================] - ETA: 0s - loss: 1.9331 - categorical_accuracy: 0.6257
# Epoch 17: saving model to model_init_2023-08-0615_38_25.467864/model-00017-1.93307-0.62567-3.12245-0.12500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.9331 - categorical_accuracy: 0.6257 - val_loss: 3.1225 - val_categorical_accuracy: 0.1250 - lr: 0.0100
# Epoch 18/50
# 11/11 [==============================] - ETA: 0s - loss: 1.9866 - categorical_accuracy: 0.5561
# Epoch 18: saving model to model_init_2023-08-0615_38_25.467864/model-00018-1.98657-0.55615-2.13568-0.50000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 1.9866 - categorical_accuracy: 0.5561 - val_loss: 2.1357 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 19/50
# 11/11 [==============================] - ETA: 0s - loss: 1.8687 - categorical_accuracy: 0.6310
# Epoch 19: saving model to model_init_2023-08-0615_38_25.467864/model-00019-1.86869-0.63102-2.29797-0.50000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.8687 - categorical_accuracy: 0.6310 - val_loss: 2.2980 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 20/50
# 11/11 [==============================] - ETA: 0s - loss: 1.8390 - categorical_accuracy: 0.6524
# Epoch 20: saving model to model_init_2023-08-0615_38_25.467864/model-00020-1.83896-0.65241-2.62349-0.50000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.8390 - categorical_accuracy: 0.6524 - val_loss: 2.6235 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 21/50
# 11/11 [==============================] - ETA: 0s - loss: 1.8708 - categorical_accuracy: 0.6364
# Epoch 21: saving model to model_init_2023-08-0615_38_25.467864/model-00021-1.87078-0.63636-1.69619-0.75000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.8708 - categorical_accuracy: 0.6364 - val_loss: 1.6962 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 22/50
# 11/11 [==============================] - ETA: 0s - loss: 1.7653 - categorical_accuracy: 0.7380
# Epoch 22: saving model to model_init_2023-08-0615_38_25.467864/model-00022-1.76529-0.73797-2.02538-0.50000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.7653 - categorical_accuracy: 0.7380 - val_loss: 2.0254 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 23/50
# 11/11 [==============================] - ETA: 0s - loss: 1.7214 - categorical_accuracy: 0.6684
# Epoch 23: saving model to model_init_2023-08-0615_38_25.467864/model-00023-1.72139-0.66845-2.00634-0.50000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.7214 - categorical_accuracy: 0.6684 - val_loss: 2.0063 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 24/50
# 11/11 [==============================] - ETA: 0s - loss: 1.8032 - categorical_accuracy: 0.6845
# Epoch 24: saving model to model_init_2023-08-0615_38_25.467864/model-00024-1.80317-0.68449-2.64787-0.25000.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.8032 - categorical_accuracy: 0.6845 - val_loss: 2.6479 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 25/50
# 11/11 [==============================] - ETA: 0s - loss: 1.7211 - categorical_accuracy: 0.7112
# Epoch 25: saving model to model_init_2023-08-0615_38_25.467864/model-00025-1.72106-0.71123-1.49100-0.75000.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.7211 - categorical_accuracy: 0.7112 - val_loss: 1.4910 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 26/50
# 11/11 [==============================] - ETA: 0s - loss: 1.6317 - categorical_accuracy: 0.7380
# Epoch 26: saving model to model_init_2023-08-0615_38_25.467864/model-00026-1.63166-0.73797-2.11434-0.50000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 1.6317 - categorical_accuracy: 0.7380 - val_loss: 2.1143 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 27/50
# 11/11 [==============================] - ETA: 0s - loss: 1.6174 - categorical_accuracy: 0.7326
# Epoch 27: saving model to model_init_2023-08-0615_38_25.467864/model-00027-1.61736-0.73262-2.38812-0.37500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.6174 - categorical_accuracy: 0.7326 - val_loss: 2.3881 - val_categorical_accuracy: 0.3750 - lr: 0.0100
# Epoch 28/50
# 11/11 [==============================] - ETA: 0s - loss: 1.6113 - categorical_accuracy: 0.7487
# Epoch 28: saving model to model_init_2023-08-0615_38_25.467864/model-00028-1.61131-0.74866-1.51316-0.62500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 1.6113 - categorical_accuracy: 0.7487 - val_loss: 1.5132 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 29/50
# 11/11 [==============================] - ETA: 0s - loss: 1.5778 - categorical_accuracy: 0.7647
# Epoch 29: saving model to model_init_2023-08-0615_38_25.467864/model-00029-1.57778-0.76471-1.87319-0.75000.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.5778 - categorical_accuracy: 0.7647 - val_loss: 1.8732 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 30/50
# 11/11 [==============================] - ETA: 0s - loss: 1.5330 - categorical_accuracy: 0.7701
# Epoch 30: saving model to model_init_2023-08-0615_38_25.467864/model-00030-1.53299-0.77005-1.83597-0.75000.h5
# 11/11 [==============================] - 25s 3s/step - loss: 1.5330 - categorical_accuracy: 0.7701 - val_loss: 1.8360 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 31/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4997 - categorical_accuracy: 0.8021
# Epoch 31: saving model to model_init_2023-08-0615_38_25.467864/model-00031-1.49969-0.80214-1.86316-0.75000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.4997 - categorical_accuracy: 0.8021 - val_loss: 1.8632 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 32/50
# 11/11 [==============================] - ETA: 0s - loss: 1.5872 - categorical_accuracy: 0.7326
# Epoch 32: saving model to model_init_2023-08-0615_38_25.467864/model-00032-1.58725-0.73262-1.97928-0.75000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.5872 - categorical_accuracy: 0.7326 - val_loss: 1.9793 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 33/50
# 11/11 [==============================] - ETA: 0s - loss: 1.5081 - categorical_accuracy: 0.7754
# Epoch 33: saving model to model_init_2023-08-0615_38_25.467864/model-00033-1.50810-0.77540-1.45802-0.62500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.5081 - categorical_accuracy: 0.7754 - val_loss: 1.4580 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 34/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4141 - categorical_accuracy: 0.8289
# Epoch 34: saving model to model_init_2023-08-0615_38_25.467864/model-00034-1.41415-0.82888-1.94784-0.62500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 1.4141 - categorical_accuracy: 0.8289 - val_loss: 1.9478 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 35/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4885 - categorical_accuracy: 0.7433
# Epoch 35: saving model to model_init_2023-08-0615_38_25.467864/model-00035-1.48849-0.74332-1.82213-0.62500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.4885 - categorical_accuracy: 0.7433 - val_loss: 1.8221 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 36/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4243 - categorical_accuracy: 0.8235
# Epoch 36: saving model to model_init_2023-08-0615_38_25.467864/model-00036-1.42433-0.82353-2.02664-0.50000.h5
# 11/11 [==============================] - 25s 3s/step - loss: 1.4243 - categorical_accuracy: 0.8235 - val_loss: 2.0266 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 37/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4150 - categorical_accuracy: 0.8663
# Epoch 37: saving model to model_init_2023-08-0615_38_25.467864/model-00037-1.41505-0.86631-2.13980-0.62500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.4150 - categorical_accuracy: 0.8663 - val_loss: 2.1398 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 38/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3607 - categorical_accuracy: 0.8610
# Epoch 38: saving model to model_init_2023-08-0615_38_25.467864/model-00038-1.36066-0.86096-2.00987-0.50000.h5
# 11/11 [==============================] - 22s 2s/step - loss: 1.3607 - categorical_accuracy: 0.8610 - val_loss: 2.0099 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 39/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4109 - categorical_accuracy: 0.8021
# Epoch 39: saving model to model_init_2023-08-0615_38_25.467864/model-00039-1.41089-0.80214-1.35493-0.87500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 1.4109 - categorical_accuracy: 0.8021 - val_loss: 1.3549 - val_categorical_accuracy: 0.8750 - lr: 0.0100
# Epoch 40/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3381 - categorical_accuracy: 0.8396
# Epoch 40: saving model to model_init_2023-08-0615_38_25.467864/model-00040-1.33806-0.83957-1.91801-0.50000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.3381 - categorical_accuracy: 0.8396 - val_loss: 1.9180 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 41/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4155 - categorical_accuracy: 0.8342
# Epoch 41: saving model to model_init_2023-08-0615_38_25.467864/model-00041-1.41553-0.83422-2.85106-0.25000.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.4155 - categorical_accuracy: 0.8342 - val_loss: 2.8511 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 42/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3293 - categorical_accuracy: 0.8503
# Epoch 42: saving model to model_init_2023-08-0615_38_25.467864/model-00042-1.32929-0.85027-2.09460-0.50000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 1.3293 - categorical_accuracy: 0.8503 - val_loss: 2.0946 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 43/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3226 - categorical_accuracy: 0.8396
# Epoch 43: saving model to model_init_2023-08-0615_38_25.467864/model-00043-1.32257-0.83957-1.26565-0.87500.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.3226 - categorical_accuracy: 0.8396 - val_loss: 1.2656 - val_categorical_accuracy: 0.8750 - lr: 0.0100
# Epoch 44/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2991 - categorical_accuracy: 0.8717
# Epoch 44: saving model to model_init_2023-08-0615_38_25.467864/model-00044-1.29906-0.87166-1.53968-0.75000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.2991 - categorical_accuracy: 0.8717 - val_loss: 1.5397 - val_categorical_accuracy: 0.7500 - lr: 0.0100
# Epoch 45/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3314 - categorical_accuracy: 0.8235
# Epoch 45: saving model to model_init_2023-08-0615_38_25.467864/model-00045-1.33136-0.82353-1.32020-0.87500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.3314 - categorical_accuracy: 0.8235 - val_loss: 1.3202 - val_categorical_accuracy: 0.8750 - lr: 0.0100
# Epoch 46/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3445 - categorical_accuracy: 0.8235
# Epoch 46: saving model to model_init_2023-08-0615_38_25.467864/model-00046-1.34449-0.82353-1.33475-0.87500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 1.3445 - categorical_accuracy: 0.8235 - val_loss: 1.3347 - val_categorical_accuracy: 0.8750 - lr: 0.0100
# Epoch 47/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2551 - categorical_accuracy: 0.8610
# Epoch 47: saving model to model_init_2023-08-0615_38_25.467864/model-00047-1.25509-0.86096-1.96258-0.62500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.2551 - categorical_accuracy: 0.8610 - val_loss: 1.9626 - val_categorical_accuracy: 0.6250 - lr: 0.0100
# Epoch 48/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1689 - categorical_accuracy: 0.8984
# Epoch 48: saving model to model_init_2023-08-0615_38_25.467864/model-00048-1.16890-0.89840-2.69777-0.50000.h5
# 11/11 [==============================] - 25s 3s/step - loss: 1.1689 - categorical_accuracy: 0.8984 - val_loss: 2.6978 - val_categorical_accuracy: 0.5000 - lr: 0.0100
# Epoch 49/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1906 - categorical_accuracy: 0.8770
# Epoch 49: saving model to model_init_2023-08-0615_38_25.467864/model-00049-1.19058-0.87701-1.32102-0.87500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 1.1906 - categorical_accuracy: 0.8770 - val_loss: 1.3210 - val_categorical_accuracy: 0.8750 - lr: 0.0100
# Epoch 50/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2404 - categorical_accuracy: 0.8235
# Epoch 50: saving model to model_init_2023-08-0615_38_25.467864/model-00050-1.24043-0.82353-1.72302-0.62500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 1.2404 - categorical_accuracy: 0.8235 - val_loss: 1.7230 - val_categorical_accuracy: 0.6250 - lr: 0.0100
